# %%
import evaluate
from datasets import *
import numpy as np
import pathlib as pl
import pandas as pd
import torch
import ast
import os
from haystack.document_stores import FAISSDocumentStore
from haystack.nodes import DensePassageRetriever, TransformersReader, Seq2SeqGenerator
from haystack.nodes.answer_generator.transformers import _BartEli5Converter
from haystack.pipelines import Pipeline

YEAR = 2042
DPR_FINE_TUNE = False

MODEL_PATH_B = "../../data/models/BERT"
MODEL_PATH_T = "../../data/models/T5"

# %%
generated_data = load_dataset('csv', data_files=f"../../data/clean/sustainability-report-{YEAR}-squad-format.csv",
                    delimiter=";", split='train').train_test_split(test_size=0.3, shuffle=True, seed=42)

generated_data["test"] = generated_data["test"].map(
    lambda example: ast.literal_eval(example["answers"]))
generated_data["test"] = generated_data["test"].map(lambda example: {"question": example["question"], "context": example["context"], "answers": {
                                  "text": example["text"], "answer_start": example["answer_start"]}})
generated_data["test"] = generated_data["test"].map(lambda example: {"question": example["question"].replace("\n", " "), "context": example["context"].replace("\n", " "), "answers": {
                                "text": [example["answers"]["text"][0].replace("\n", " ")], "answer_start": example["answers"]["answer_start"]}})
generated_data["test"].remove_columns(["text", "answer_start"])
# Out:
# Found cached dataset csv (C:/Users/rjutr/.cache/huggingface/datasets/csv/default-dc46deea403e6d7a/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1)
# Loading cached split indices for dataset at C:\Users\rjutr\.cache\huggingface\datasets\csv\default-dc46deea403e6d7a\0.0.0\6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1\cache-8c4226c3883b9f9f.arrow and C:\Users\rjutr\.cache\huggingface\datasets\csv\default-dc46deea403e6d7a\0.0.0\6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1\cache-24d9770f6403af3d.arrow
# Loading cached processed dataset at C:\Users\rjutr\.cache\huggingface\datasets\csv\default-dc46deea403e6d7a\0.0.0\6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1\cache-47e77242f5a0d387.arrow
# Loading cached processed dataset at C:\Users\rjutr\.cache\huggingface\datasets\csv\default-dc46deea403e6d7a\0.0.0\6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1\cache-cb788cd2e517f2b5.arrow
# Loading cached processed dataset at C:\Users\rjutr\.cache\huggingface\datasets\csv\default-dc46deea403e6d7a\0.0.0\6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1\cache-4957f1c2e4c5cb13.arrow
# Dataset({
#     features: ['question', 'context', 'answers', 'id'],
#     num_rows: 162
# })

# %%
document_store = FAISSDocumentStore.load(index_path="document_store.faiss", config_path="document_store.json")

# %%
retriever = DensePassageRetriever.load(load_dir=f"../../data/models/DPR/{YEAR}", document_store=document_store, use_gpu=True)
# Out:
# c:\Users\rjutr\miniconda3\envs\project_ds_2\lib\site-packages\torch\_utils.py:776: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()

# %%
# Set the device
device = torch.device(
    "cuda") if torch.cuda.is_available() else torch.device("cpu")

# Define the prediction function
def inference_answer(model, question):
    question = question
    with torch.no_grad():
        outputs = model.run(query=question, params={"Model": {"top_k": 1}, "Retriever": {"top_k": 1}})
    return outputs["answers"][0].answer, outputs["documents"][0].content

# %%
results = {
    "Model": [],
    "Question": [],
    "Ground Truth Context": [],
    "Ground Truth Answer": [],
    "Retrieved Context": [],
    "Extracted/Generated Answer": []
}

# %%
reader = TransformersReader(model_name_or_path=f"{MODEL_PATH_B}/roberta-base-squad2-finetuned-NLB-QA-2042-full_combined", use_gpu=True)
pipe = Pipeline()
pipe.add_node(component=retriever, name="Retriever", inputs=["Query"])
pipe.add_node(component=reader, name="Model", inputs=["Retriever"])



for idx in range(generated_data["test"].shape[0]):
    results["Model"].append("roberta")
    row = generated_data["test"][idx]
    results["Question"].append(row["question"].strip())
    results["Ground Truth Context"].append(row["context"])
    results["Ground Truth Answer"].append(row["answers"]["text"][0])
    gotten_answer, gotten_context = inference_answer(pipe, row["question"].strip())
    results["Retrieved Context"].append(gotten_context)
    results["Extracted/Generated Answer"].append(gotten_answer)

del reader
del pipe
torch.cuda.empty_cache()
# Out:
# c:\Users\rjutr\miniconda3\envs\project_ds_2\lib\site-packages\transformers\pipelines\base.py:1070: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(

# %%
reader = TransformersReader(model_name_or_path=f"{MODEL_PATH_B}/distilbert-base-cased-distilled-squad-finetuned-NLB-QA-2042-full_combined", use_gpu=True)
pipe = Pipeline()
pipe.add_node(component=retriever, name="Retriever", inputs=["Query"])
pipe.add_node(component=reader, name="Model", inputs=["Retriever"])



for idx in range(generated_data["test"].shape[0]):
    results["Model"].append("distilbert")
    row = generated_data["test"][idx]
    results["Question"].append(row["question"].strip())
    results["Ground Truth Context"].append(row["context"])
    results["Ground Truth Answer"].append(row["answers"]["text"][0])
    gotten_answer, gotten_context = inference_answer(pipe, row["question"].strip())
    results["Retrieved Context"].append(gotten_context)
    results["Extracted/Generated Answer"].append(gotten_answer)

del reader
del pipe
torch.cuda.empty_cache()

# %%
generator = Seq2SeqGenerator(model_name_or_path=f"{MODEL_PATH_T}/t5-base-finetuned-squadv2-finetuned-NLB-QA-2042-full_combined", input_converter=_BartEli5Converter(), use_gpu=True)
pipe = Pipeline()
pipe.add_node(component=retriever, name="Retriever", inputs=["Query"])
pipe.add_node(component=generator, name="Model", inputs=["Retriever"])



for idx in range(generated_data["test"].shape[0]):
    results["Model"].append("t5-base")
    row = generated_data["test"][idx]
    results["Question"].append(row["question"].strip())
    results["Ground Truth Context"].append(row["context"])
    results["Ground Truth Answer"].append(row["answers"]["text"][0])
    gotten_answer, gotten_context = inference_answer(pipe, row["question"].strip())
    results["Retrieved Context"].append(gotten_context)
    results["Extracted/Generated Answer"].append(gotten_answer)

del generator
del pipe
torch.cuda.empty_cache()

# %%
generator = Seq2SeqGenerator(model_name_or_path=f"{MODEL_PATH_T}/t5-small-finetuned-squadv2-finetuned-NLB-QA-2042-full_combined", input_converter=_BartEli5Converter(), use_gpu=True)
pipe = Pipeline()
pipe.add_node(component=retriever, name="Retriever", inputs=["Query"])
pipe.add_node(component=generator, name="Model", inputs=["Retriever"])



for idx in range(generated_data["test"].shape[0]):
    results["Model"].append("t5-small")
    row = generated_data["test"][idx]
    results["Question"].append(row["question"].strip())
    results["Ground Truth Context"].append(row["context"])
    results["Ground Truth Answer"].append(row["answers"]["text"][0])
    gotten_answer, gotten_context = inference_answer(pipe, row["question"].strip())
    results["Retrieved Context"].append(gotten_context)
    results["Extracted/Generated Answer"].append(gotten_answer)

del generator
del pipe
torch.cuda.empty_cache()

# %%
results_df = pd.DataFrame(results)

# %%
def get_answers_for_question(question):
    with pd.option_context('display.max_rows', None, 'display.max_columns', None):
        display(results_df[results_df["Question"] == question])

# %%
get_answers_for_question("How many modules did the 2022 ECB Climate Stress test exercise consist of?")
# Out:
#           Model  \
# 1       roberta
# 163  distilbert
# 325     t5-base
# 487    t5-small
#
#                                                                        Question  \
# 1    How many modules did the 2022 ECB Climate Stress test exercise consist of?
# 163  How many modules did the 2022 ECB Climate Stress test exercise consist of?
# 325  How many modules did the 2022 ECB Climate Stress test exercise consist of?
# 487  How many modules did the 2022 ECB Climate Stress test exercise consist of?
#
#                                                                 Ground Truth Context  \
# 1    was includedinto 2022 ECB Climate Stress test exercise, consisted of threemo...
# 163  was includedinto 2022 ECB Climate Stress test exercise, consisted of threemo...
# 325  was includedinto 2022 ECB Climate Stress test exercise, consisted of threemo...
# 487  was includedinto 2022 ECB Climate Stress test exercise, consisted of threemo...
#
#     Ground Truth Answer  \
# 1                 three
# 163               three
# 325               three
# 487               three
#
#                                                                    Retrieved Context  \
# 1    The results of climate stress tests showed no material\nimpacts on the Group...
# 163  The results of climate stress tests showed no material\nimpacts on the Group...
# 325  The results of climate stress tests showed no material\nimpacts on the Group...
# 487  The results of climate stress tests showed no material\nimpacts on the Group...
#
#     Extracted/Generated Answer
# 1                        three
# 163                      three
# 325                     three
# 487                     three

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(results_df)
# Out:
#           Model  \
# 0       roberta
# 1       roberta
# 2       roberta
# 3       roberta
# 4       roberta
# 5       roberta
# 6       roberta
# 7       roberta
# 8       roberta
# 9       roberta
# 10      roberta
# 11      roberta
# 12      roberta
# 13      roberta
# 14      roberta
# 15      roberta
# 16      roberta
# 17      roberta
# 18      roberta
# 19      roberta
# 20      roberta
# 21      roberta
# 22      roberta
# 23      roberta
# 24      roberta
# 25      roberta
# 26      roberta
# 27      roberta
# 28      roberta
# 29      roberta
# 30      roberta
# 31      roberta
# 32      roberta
# 33      roberta
# 34      roberta
# 35      roberta
# 36      roberta
# 37      roberta
# 38      roberta
# 39      roberta
# 40      roberta
# 41      roberta
# 42      roberta
# 43      roberta
# 44      roberta
# 45      roberta
# 46      roberta
# 47      roberta
# 48      roberta
# 49      roberta
# 50      roberta
# 51      roberta
# 52      roberta
# 53      roberta
# 54      roberta
# 55      roberta
# 56      roberta
# 57      roberta
# 58      roberta
# 59      roberta
# 60      roberta
# 61      roberta
# 62      roberta
# 63      roberta
# 64      roberta
# 65      roberta
# 66      roberta
# 67      roberta
# 68      roberta
# 69      roberta
# 70      roberta
# 71      roberta
# 72      roberta
# 73      roberta
# 74      roberta
# 75      roberta
# 76      roberta
# 77      roberta
# 78      roberta
# 79      roberta
# 80      roberta
# 81      roberta
# 82      roberta
# 83      roberta
# 84      roberta
# 85      roberta
# 86      roberta
# 87      roberta
# 88      roberta
# 89      roberta
# 90      roberta
# 91      roberta
# 92      roberta
# 93      roberta
# 94      roberta
# 95      roberta
# 96      roberta
# 97      roberta
# 98      roberta
# 99      roberta
# 100     roberta
# 101     roberta
# 102     roberta
# 103     roberta
# 104     roberta
# 105     roberta
# 106     roberta
# 107     roberta
# 108     roberta
# 109     roberta
# 110     roberta
# 111     roberta
# 112     roberta
# 113     roberta
# 114     roberta
# 115     roberta
# 116     roberta
# 117     roberta
# 118     roberta
# 119     roberta
# 120     roberta
# 121     roberta
# 122     roberta
# 123     roberta
# 124     roberta
# 125     roberta
# 126     roberta
# 127     roberta
# 128     roberta
# 129     roberta
# 130     roberta
# 131     roberta
# 132     roberta
# 133     roberta
# 134     roberta
# 135     roberta
# 136     roberta
# 137     roberta
# 138     roberta
# 139     roberta
# 140     roberta
# 141     roberta
# 142     roberta
# 143     roberta
# 144     roberta
# 145     roberta
# 146     roberta
# 147     roberta
# 148     roberta
# 149     roberta
# 150     roberta
# 151     roberta
# 152     roberta
# 153     roberta
# 154     roberta
# 155     roberta
# 156     roberta
# 157     roberta
# 158     roberta
# 159     roberta
# 160     roberta
# 161     roberta
# 162  distilbert
# 163  distilbert
# 164  distilbert
# 165  distilbert
# 166  distilbert
# 167  distilbert
# 168  distilbert
# 169  distilbert
# 170  distilbert
# 171  distilbert
# 172  distilbert
# 173  distilbert
# 174  distilbert
# 175  distilbert
# 176  distilbert
# 177  distilbert
# 178  distilbert
# 179  distilbert
# 180  distilbert
# 181  distilbert
# 182  distilbert
# 183  distilbert
# 184  distilbert
# 185  distilbert
# 186  distilbert
# 187  distilbert
# 188  distilbert
# 189  distilbert
# 190  distilbert
# 191  distilbert
# 192  distilbert
# 193  distilbert
# 194  distilbert
# 195  distilbert
# 196  distilbert
# 197  distilbert
# 198  distilbert
# 199  distilbert
# 200  distilbert
# 201  distilbert
# 202  distilbert
# 203  distilbert
# 204  distilbert
# 205  distilbert
# 206  distilbert
# 207  distilbert
# 208  distilbert
# 209  distilbert
# 210  distilbert
# 211  distilbert
# 212  distilbert
# 213  distilbert
# 214  distilbert
# 215  distilbert
# 216  distilbert
# 217  distilbert
# 218  distilbert
# 219  distilbert
# 220  distilbert
# 221  distilbert
# 222  distilbert
# 223  distilbert
# 224  distilbert
# 225  distilbert
# 226  distilbert
# 227  distilbert
# 228  distilbert
# 229  distilbert
# 230  distilbert
# 231  distilbert
# 232  distilbert
# 233  distilbert
# 234  distilbert
# 235  distilbert
# 236  distilbert
# 237  distilbert
# 238  distilbert
# 239  distilbert
# 240  distilbert
# 241  distilbert
# 242  distilbert
# 243  distilbert
# 244  distilbert
# 245  distilbert
# 246  distilbert
# 247  distilbert
# 248  distilbert
# 249  distilbert
# 250  distilbert
# 251  distilbert
# 252  distilbert
# 253  distilbert
# 254  distilbert
# 255  distilbert
# 256  distilbert
# 257  distilbert
# 258  distilbert
# 259  distilbert
# 260  distilbert
# 261  distilbert
# 262  distilbert
# 263  distilbert
# 264  distilbert
# 265  distilbert
# 266  distilbert
# 267  distilbert
# 268  distilbert
# 269  distilbert
# 270  distilbert
# 271  distilbert
# 272  distilbert
# 273  distilbert
# 274  distilbert
# 275  distilbert
# 276  distilbert
# 277  distilbert
# 278  distilbert
# 279  distilbert
# 280  distilbert
# 281  distilbert
# 282  distilbert
# 283  distilbert
# 284  distilbert
# 285  distilbert
# 286  distilbert
# 287  distilbert
# 288  distilbert
# 289  distilbert
# 290  distilbert
# 291  distilbert
# 292  distilbert
# 293  distilbert
# 294  distilbert
# 295  distilbert
# 296  distilbert
# 297  distilbert
# 298  distilbert
# 299  distilbert
# 300  distilbert
# 301  distilbert
# 302  distilbert
# 303  distilbert
# 304  distilbert
# 305  distilbert
# 306  distilbert
# 307  distilbert
# 308  distilbert
# 309  distilbert
# 310  distilbert
# 311  distilbert
# 312  distilbert
# 313  distilbert
# 314  distilbert
# 315  distilbert
# 316  distilbert
# 317  distilbert
# 318  distilbert
# 319  distilbert
# 320  distilbert
# 321  distilbert
# 322  distilbert
# 323  distilbert
# 324     t5-base
# 325     t5-base
# 326     t5-base
# 327     t5-base
# 328     t5-base
# 329     t5-base
# 330     t5-base
# 331     t5-base
# 332     t5-base
# 333     t5-base
# 334     t5-base
# 335     t5-base
# 336     t5-base
# 337     t5-base
# 338     t5-base
# 339     t5-base
# 340     t5-base
# 341     t5-base
# 342     t5-base
# 343     t5-base
# 344     t5-base
# 345     t5-base
# 346     t5-base
# 347     t5-base
# 348     t5-base
# 349     t5-base
# 350     t5-base
# 351     t5-base
# 352     t5-base
# 353     t5-base
# 354     t5-base
# 355     t5-base
# 356     t5-base
# 357     t5-base
# 358     t5-base
# 359     t5-base
# 360     t5-base
# 361     t5-base
# 362     t5-base
# 363     t5-base
# 364     t5-base
# 365     t5-base
# 366     t5-base
# 367     t5-base
# 368     t5-base
# 369     t5-base
# 370     t5-base
# 371     t5-base
# 372     t5-base
# 373     t5-base
# 374     t5-base
# 375     t5-base
# 376     t5-base
# 377     t5-base
# 378     t5-base
# 379     t5-base
# 380     t5-base
# 381     t5-base
# 382     t5-base
# 383     t5-base
# 384     t5-base
# 385     t5-base
# 386     t5-base
# 387     t5-base
# 388     t5-base
# 389     t5-base
# 390     t5-base
# 391     t5-base
# 392     t5-base
# 393     t5-base
# 394     t5-base
# 395     t5-base
# 396     t5-base
# 397     t5-base
# 398     t5-base
# 399     t5-base
# 400     t5-base
# 401     t5-base
# 402     t5-base
# 403     t5-base
# 404     t5-base
# 405     t5-base
# 406     t5-base
# 407     t5-base
# 408     t5-base
# 409     t5-base
# 410     t5-base
# 411     t5-base
# 412     t5-base
# 413     t5-base
# 414     t5-base
# 415     t5-base
# 416     t5-base
# 417     t5-base
# 418     t5-base
# 419     t5-base
# 420     t5-base
# 421     t5-base
# 422     t5-base
# 423     t5-base
# 424     t5-base
# 425     t5-base
# 426     t5-base
# 427     t5-base
# 428     t5-base
# 429     t5-base
# 430     t5-base
# 431     t5-base
# 432     t5-base
# 433     t5-base
# 434     t5-base
# 435     t5-base
# 436     t5-base
# 437     t5-base
# 438     t5-base
# 439     t5-base
# 440     t5-base
# 441     t5-base
# 442     t5-base
# 443     t5-base
# 444     t5-base
# 445     t5-base
# 446     t5-base
# 447     t5-base
# 448     t5-base
# 449     t5-base
# 450     t5-base
# 451     t5-base
# 452     t5-base
# 453     t5-base
# 454     t5-base
# 455     t5-base
# 456     t5-base
# 457     t5-base
# 458     t5-base
# 459     t5-base
# 460     t5-base
# 461     t5-base
# 462     t5-base
# 463     t5-base
# 464     t5-base
# 465     t5-base
# 466     t5-base
# 467     t5-base
# 468     t5-base
# 469     t5-base
# 470     t5-base
# 471     t5-base
# 472     t5-base
# 473     t5-base
# 474     t5-base
# 475     t5-base
# 476     t5-base
# 477     t5-base
# 478     t5-base
# 479     t5-base
# 480     t5-base
# 481     t5-base
# 482     t5-base
# 483     t5-base
# 484     t5-base
# 485     t5-base
# 486    t5-small
# 487    t5-small
# 488    t5-small
# 489    t5-small
# 490    t5-small
# 491    t5-small
# 492    t5-small
# 493    t5-small
# 494    t5-small
# 495    t5-small
# 496    t5-small
# 497    t5-small
# 498    t5-small
# 499    t5-small
# 500    t5-small
# 501    t5-small
# 502    t5-small
# 503    t5-small
# 504    t5-small
# 505    t5-small
# 506    t5-small
# 507    t5-small
# 508    t5-small
# 509    t5-small
# 510    t5-small
# 511    t5-small
# 512    t5-small
# 513    t5-small
# 514    t5-small
# 515    t5-small
# 516    t5-small
# 517    t5-small
# 518    t5-small
# 519    t5-small
# 520    t5-small
# 521    t5-small
# 522    t5-small
# 523    t5-small
# 524    t5-small
# 525    t5-small
# 526    t5-small
# 527    t5-small
# 528    t5-small
# 529    t5-small
# 530    t5-small
# 531    t5-small
# 532    t5-small
# 533    t5-small
# 534    t5-small
# 535    t5-small
# 536    t5-small
# 537    t5-small
# 538    t5-small
# 539    t5-small
# 540    t5-small
# 541    t5-small
# 542    t5-small
# 543    t5-small
# 544    t5-small
# 545    t5-small
# 546    t5-small
# 547    t5-small
# 548    t5-small
# 549    t5-small
# 550    t5-small
# 551    t5-small
# 552    t5-small
# 553    t5-small
# 554    t5-small
# 555    t5-small
# 556    t5-small
# 557    t5-small
# 558    t5-small
# 559    t5-small
# 560    t5-small
# 561    t5-small
# 562    t5-small
# 563    t5-small
# 564    t5-small
# 565    t5-small
# 566    t5-small
# 567    t5-small
# 568    t5-small
# 569    t5-small
# 570    t5-small
# 571    t5-small
# 572    t5-small
# 573    t5-small
# 574    t5-small
# 575    t5-small
# 576    t5-small
# 577    t5-small
# 578    t5-small
# 579    t5-small
# 580    t5-small
# 581    t5-small
# 582    t5-small
# 583    t5-small
# 584    t5-small
# 585    t5-small
# 586    t5-small
# 587    t5-small
# 588    t5-small
# 589    t5-small
# 590    t5-small
# 591    t5-small
# 592    t5-small
# 593    t5-small
# 594    t5-small
# 595    t5-small
# 596    t5-small
# 597    t5-small
# 598    t5-small
# 599    t5-small
# 600    t5-small
# 601    t5-small
# 602    t5-small
# 603    t5-small
# 604    t5-small
# 605    t5-small
# 606    t5-small
# 607    t5-small
# 608    t5-small
# 609    t5-small
# 610    t5-small
# 611    t5-small
# 612    t5-small
# 613    t5-small
# 614    t5-small
# 615    t5-small
# 616    t5-small
# 617    t5-small
# 618    t5-small
# 619    t5-small
# 620    t5-small
# 621    t5-small
# 622    t5-small
# 623    t5-small
# 624    t5-small
# 625    t5-small
# 626    t5-small
# 627    t5-small
# 628    t5-small
# 629    t5-small
# 630    t5-small
# 631    t5-small
# 632    t5-small
# 633    t5-small
# 634    t5-small
# 635    t5-small
# 636    t5-small
# 637    t5-small
# 638    t5-small
# 639    t5-small
# 640    t5-small
# 641    t5-small
# 642    t5-small
# 643    t5-small
# 644    t5-small
# 645    t5-small
# 646    t5-small
# 647    t5-small
#
#                                                                             Question  \
# 0     How much CO2 did we reduce by using electric vehicles instead of liquid fuels?
# 1         How many modules did the 2022 ECB Climate Stress test exercise consist of?
# 2                                                  How many behaviours were defined?
# 3    How much did the bank reduce the use of paper in 2022 compared to the previo...
# 4               What are the key strategic areas of operations of the Group in 2020?
# 5            What percentage of NLB Group employees have a tertiary education level?
# 6    In what year did the Bank sign a Contract of Guarantees with the Multilatera...
# 7                         What is the name of the Non-Financial Reporting Directive?
# 8                                How many targets did the NLB Bank announce in 2021?
# 9            How many branches does NLB Group have in all markets where it operates?
# 10                   How many Slovenian companies joined the GREENVISION initiative?
# 11                           What do employees in banks possess better knowledge of?
# 12                                                         What does ECRA stand for?
# 13                In 2022, how many hours/employee did NLB employees do in training?
# 14                            How many material issues did Senior Management assess?
# 15   What other measures are there for reducing costs and streamlining the Banks ...
# 16                                                      How many trees did NLB save?
# 17                                          How many trees were planted on Jahorina?
# 18           When was the impact analysis based on the UN PRB methodology conducted?
# 19                    What percentage of all employees have been internally audited?
# 20   By 2030, what percentage of all electric energy used in NLB Group will come ...
# 21           When was Komercijalna Banka a.d. Beograd and its subsidiaries finished?
# 22                             How many countries are there in which we are present?
# 23                 What percentage of the Bank is owned by the Republic of Slovenia?
# 24                         What does the report accurately and completely represent?
# 25                                            Who is the leader of the SHIMMPO team?
# 26                                    How many clients does Komercijalna banka have?
# 27                                   How many employees took parental leave in 2022?
# 28                  How many shareholders did the Supervisory Board address in 2022?
# 29       In what year were concrete targets included in the Banks performance plans?
# 30                                                                 What is the ESMS?
# 31                              How many employees took part in training programmes?
# 32                      How many employees are on the Komercijna Banka banking team?
# 33                    What is the framework for reporting non-financial information?
# 34                                              Where is Komercijalna banka located?
# 35                                       What does NLB Group aim to achieve in 2022?
# 36                     What is the acronym for the European Social Market Authority?
# 37                          How many employees were in NLB Group at the end of 2020?
# 38         How many new employees were employed by the Republic of Slovenia in 2020?
# 39          How many participants took part in standard training programmes in 2020?
# 40   How much new green loan volume did NLB Group generate for micro and corporat...
# 41                                          What type of structure does H stand for?
# 42                           Compliance and integrity were established in what year?
# 43        What is one of the most important building blocks of the Banks governance?
# 44         How many consecutive years did Top Employer receive the First ESG Rating?
# 45                                       What percentage of those who left were men?
# 46   What defines the basic goals and principles of protection of people, facilit...
# 47                       In what year did NLB Group organize its first Investor Day?
# 48                                            What is the share capital of the bank?
# 49                                                     What does ESMS aim to manage?
# 50                                How many employees departed from NLB d.d. in 2020?
# 51   How can employees report potentially non-ethical or inappropriate business p...
# 52                                  Who implemented the Women in Business programme?
# 53   How much of all electricity used in NLB Group will come from zero-carbon sou...
# 54   In what year did the NLB Group become a signatory to the UN PRB and UNEP FI ...
# 55                 What was the turnover rate in NLB Group in 2022 compared to 2021?
# 56       What percentage of electricity was obtained from zero carbon energy source?
# 57                           How much sustainable corporate financing did we create?
# 58   How much electricity was purchased from zero-carbon sources in two largest a...
# 59      What is Slovenias most important and renowned network of advanced companies?
# 60                                  How many trees did the bank donate to Prishtina?
# 61   What country allows customers to do business remotely 24 hours a day, 7 days...
# 62                                        What is an inspiration for all of society?
# 63             What percentage of female managers were women at the end of the year?
# 64                                          How many women are in Management Boards?
# 65   When did the programme evolve into a comprehensive NLB Group Sustainability ...
# 66                       What was the consumption of various resources converted to?
# 67            When was the acquisition of Komercijalna Banka a.d. Beograd completed?
# 68   In 2022, how many hours were recorded in education about sustainability topics?
# 69                                                         When was Net established?
# 70           How many employees departed from NLB Group significant members in 2020?
# 71                          What type of paper is used per employee per working day?
# 72                         Who are the directors that are subordinated to B-2 level?
# 73   In what two cities did the electricity consumption decrease between 6% and 9...
# 74   What year was it possible to detect the activities of banks in the Slovenian...
# 75                                         What is the name of the Social GRI Topic?
# 76           What was NLB Group rated as low risk by ESG Risk rating Sustainalytics?
# 77   What does the Guide to fit and proper assessments of the European Central Ba...
# 78                       What was the percentage of staff with disabilities in 2020?
# 79                               What does the NLB Groups Code of Conduct establish?
# 80                                        What percentage of new employees were men?
# 81                             Sustainable corporate financing started in what year?
# 82                                     What does NLBs policy contain description of?
# 83                           What is NLB Prishtinas percentage of card transactions?
# 84   How many stages of personal finance management are there in the Bankarium mu...
# 85                     How often do all banks conduct a corporate engagement survey?
# 86                        How many different locations did NLB BankGo visit in 2022?
# 87   How much will NLB reduce the number of paper prints in its operations by 202...
# 88                                                          What does ESMS apply to?
# 89           How many banks represent around a third of the global banking industry?
# 90                                 How many years old is Slovenias banking heritage?
# 91                              What is constantly tested and upgraded in the Group?
# 92   What is a key enabler of the transition towards a low-carbon economy and soc...
# 93                      How many NLB members have received anti-corruption training?
# 94           What is the name of the first NLB project that supports sustainability?
# 95                                         What is respected at the NLB Group level?
# 96                     Why have we relocated our operation to a number of locations?
# 97   By what year did NLB Group form the emission calculation for the Slovenian m...
# 98                                               What does Sophos antivirus protect?
# 99                           How many EU Taxonomy - voluntary disclosures are there?
# 100                    Where is the Corporate Governance Statement of NLB published?
# 101                                                       What does FATCA stand for?
# 102  How does the Bank prevent or manage cyber risks arising from the increased v...
# 103  When will the combined measurements be combined with the results of similar ...
# 104  In what year do we plan to fully integrate Komercijalna banka into our susta...
# 105                                               Optimization of what in buildings?
# 106             What is the first reporting date for BASEL Pillar 3 ESG Disclosures?
# 107                    How many stakeholders did the materiality analysis work with?
# 108        What is NLB focused on embedding in its business processes and reporting?
# 109  In what year was a law passed that protects the energy sector from the negat...
# 110                            How many people were included in the company in 2022?
# 111             How many business lines did the NLB Group portfolio break down into?
# 112                                                        What does ESMS stand for?
# 113                                    How many women are on NLBs Supervisory Board?
# 114           What is responsible for the supervision of the correct implementation?
# 115                 What percentage of current employees are NLB Group core members?
# 116  What did the survey on ethics and compliance with the NLB and in the strateg...
# 117              What is one of the key responsibilities of the Sustainability unit?
# 118                                     How many employees worked from home in 2022?
# 119  What is prepared according to Article 17 of the Regulation on internal gover...
# 120     By 2025, what will be the share of active digital retail users in NLB Group?
# 121  When did the NLB Group offer customers loans with a sustainable financing co...
# 122  What does NLB ensure by having a common understanding of and complying with ...
# 123                 How many different sets of activities were provided in Sarajevo?
# 124  What percentage of all employees are covered by a system that has been inter...
# 125              How many big taxpayers had mutual trust status in Slovenia in 2020?
# 126               By 2022, how much of new corporate financing has been implemented?
# 127  What is the name of the school of economics and business of the University o...
# 128      What is the acronym for the Internal Liquidity Adequacy Assessment Process?
# 129              How many companies participated in the FrameOfHelp project in 2022?
# 130                                                                    What is ESMA?
# 131             What defines the values and basic rules of ethical business conduct?
# 132                                            When was Komercijalna Banka acquired?
# 133                                     What percentage of employees work from home?
# 134                                      How many subsidiary banks are in SE Europe?
# 135                               How many employees did the NLB Group have in 2019?
# 136  How many kilometers did we drive in 2020 using electric cars for business pu...
# 137                              In 2022, ESG goals were considered as part of what?
# 138                     By 2025, what percentage of paper prints were to be reduced?
# 139   What is one of the activities that the Group does not finance that is illegal?
# 140  What does NLB Group align its core strategy, decision-making, lending and in...
# 141                           What is the purpose of the Customer Experience Survey?
# 142                       What title goes to a branch where employees work together?
# 143   How many employees took part in training programmes in the baseline year 2019?
# 144                                What are NLB d.d.s operations in accordance with?
# 145  How many main stakeholder groups did the NLB Group identify through stakehol...
# 146                How much of managers in the second management level are women in?
# 147                     How much of all card transactions in NLB go through NLB Pay?
# 148                                     What does NLB Group give high importance to?
# 149          Who has the influence over sustainability-related strategic objectives?
# 150  What defines expectations and determines standards expected in our relations...
# 151              How does the Bank implement the principles of the Diversity Policy?
# 152                          What describes the management process and organization?
# 153  When did several important activities start for the purpose of calculation o...
# 154  What will exposures that are not fully supported by published Taxonomy repor...
# 155                                   How many sports clubs did NLB support in 2022?
# 156          How many workshops were organized specifically for older peoples needs?
# 157                                How many countries does the NLB Group operate in?
# 158                                         How many active clients does Group have?
# 159          NLB Pay is a mobile wallet that enables contactless payments with what?
# 160            What does the Sustainable Development unit make proposals related to?
# 161                                        What does NLB Group operate in line with?
# 162   How much CO2 did we reduce by using electric vehicles instead of liquid fuels?
# 163       How many modules did the 2022 ECB Climate Stress test exercise consist of?
# 164                                                How many behaviours were defined?
# 165  How much did the bank reduce the use of paper in 2022 compared to the previo...
# 166             What are the key strategic areas of operations of the Group in 2020?
# 167          What percentage of NLB Group employees have a tertiary education level?
# 168  In what year did the Bank sign a Contract of Guarantees with the Multilatera...
# 169                       What is the name of the Non-Financial Reporting Directive?
# 170                              How many targets did the NLB Bank announce in 2021?
# 171          How many branches does NLB Group have in all markets where it operates?
# 172                  How many Slovenian companies joined the GREENVISION initiative?
# 173                          What do employees in banks possess better knowledge of?
# 174                                                        What does ECRA stand for?
# 175               In 2022, how many hours/employee did NLB employees do in training?
# 176                           How many material issues did Senior Management assess?
# 177  What other measures are there for reducing costs and streamlining the Banks ...
# 178                                                     How many trees did NLB save?
# 179                                         How many trees were planted on Jahorina?
# 180          When was the impact analysis based on the UN PRB methodology conducted?
# 181                   What percentage of all employees have been internally audited?
# 182  By 2030, what percentage of all electric energy used in NLB Group will come ...
# 183          When was Komercijalna Banka a.d. Beograd and its subsidiaries finished?
# 184                            How many countries are there in which we are present?
# 185                What percentage of the Bank is owned by the Republic of Slovenia?
# 186                        What does the report accurately and completely represent?
# 187                                           Who is the leader of the SHIMMPO team?
# 188                                   How many clients does Komercijalna banka have?
# 189                                  How many employees took parental leave in 2022?
# 190                 How many shareholders did the Supervisory Board address in 2022?
# 191      In what year were concrete targets included in the Banks performance plans?
# 192                                                                What is the ESMS?
# 193                             How many employees took part in training programmes?
# 194                     How many employees are on the Komercijna Banka banking team?
# 195                   What is the framework for reporting non-financial information?
# 196                                             Where is Komercijalna banka located?
# 197                                      What does NLB Group aim to achieve in 2022?
# 198                    What is the acronym for the European Social Market Authority?
# 199                         How many employees were in NLB Group at the end of 2020?
# 200        How many new employees were employed by the Republic of Slovenia in 2020?
# 201         How many participants took part in standard training programmes in 2020?
# 202  How much new green loan volume did NLB Group generate for micro and corporat...
# 203                                         What type of structure does H stand for?
# 204                          Compliance and integrity were established in what year?
# 205       What is one of the most important building blocks of the Banks governance?
# 206        How many consecutive years did Top Employer receive the First ESG Rating?
# 207                                      What percentage of those who left were men?
# 208  What defines the basic goals and principles of protection of people, facilit...
# 209                      In what year did NLB Group organize its first Investor Day?
# 210                                           What is the share capital of the bank?
# 211                                                    What does ESMS aim to manage?
# 212                               How many employees departed from NLB d.d. in 2020?
# 213  How can employees report potentially non-ethical or inappropriate business p...
# 214                                 Who implemented the Women in Business programme?
# 215  How much of all electricity used in NLB Group will come from zero-carbon sou...
# 216  In what year did the NLB Group become a signatory to the UN PRB and UNEP FI ...
# 217                What was the turnover rate in NLB Group in 2022 compared to 2021?
# 218      What percentage of electricity was obtained from zero carbon energy source?
# 219                          How much sustainable corporate financing did we create?
# 220  How much electricity was purchased from zero-carbon sources in two largest a...
# 221     What is Slovenias most important and renowned network of advanced companies?
# 222                                 How many trees did the bank donate to Prishtina?
# 223  What country allows customers to do business remotely 24 hours a day, 7 days...
# 224                                       What is an inspiration for all of society?
# 225            What percentage of female managers were women at the end of the year?
# 226                                         How many women are in Management Boards?
# 227  When did the programme evolve into a comprehensive NLB Group Sustainability ...
# 228                      What was the consumption of various resources converted to?
# 229           When was the acquisition of Komercijalna Banka a.d. Beograd completed?
# 230  In 2022, how many hours were recorded in education about sustainability topics?
# 231                                                        When was Net established?
# 232          How many employees departed from NLB Group significant members in 2020?
# 233                         What type of paper is used per employee per working day?
# 234                        Who are the directors that are subordinated to B-2 level?
# 235  In what two cities did the electricity consumption decrease between 6% and 9...
# 236  What year was it possible to detect the activities of banks in the Slovenian...
# 237                                        What is the name of the Social GRI Topic?
# 238          What was NLB Group rated as low risk by ESG Risk rating Sustainalytics?
# 239  What does the Guide to fit and proper assessments of the European Central Ba...
# 240                      What was the percentage of staff with disabilities in 2020?
# 241                              What does the NLB Groups Code of Conduct establish?
# 242                                       What percentage of new employees were men?
# 243                            Sustainable corporate financing started in what year?
# 244                                    What does NLBs policy contain description of?
# 245                          What is NLB Prishtinas percentage of card transactions?
# 246  How many stages of personal finance management are there in the Bankarium mu...
# 247                    How often do all banks conduct a corporate engagement survey?
# 248                       How many different locations did NLB BankGo visit in 2022?
# 249  How much will NLB reduce the number of paper prints in its operations by 202...
# 250                                                         What does ESMS apply to?
# 251          How many banks represent around a third of the global banking industry?
# 252                                How many years old is Slovenias banking heritage?
# 253                             What is constantly tested and upgraded in the Group?
# 254  What is a key enabler of the transition towards a low-carbon economy and soc...
# 255                     How many NLB members have received anti-corruption training?
# 256          What is the name of the first NLB project that supports sustainability?
# 257                                        What is respected at the NLB Group level?
# 258                    Why have we relocated our operation to a number of locations?
# 259  By what year did NLB Group form the emission calculation for the Slovenian m...
# 260                                              What does Sophos antivirus protect?
# 261                          How many EU Taxonomy - voluntary disclosures are there?
# 262                    Where is the Corporate Governance Statement of NLB published?
# 263                                                       What does FATCA stand for?
# 264  How does the Bank prevent or manage cyber risks arising from the increased v...
# 265  When will the combined measurements be combined with the results of similar ...
# 266  In what year do we plan to fully integrate Komercijalna banka into our susta...
# 267                                               Optimization of what in buildings?
# 268             What is the first reporting date for BASEL Pillar 3 ESG Disclosures?
# 269                    How many stakeholders did the materiality analysis work with?
# 270        What is NLB focused on embedding in its business processes and reporting?
# 271  In what year was a law passed that protects the energy sector from the negat...
# 272                            How many people were included in the company in 2022?
# 273             How many business lines did the NLB Group portfolio break down into?
# 274                                                        What does ESMS stand for?
# 275                                    How many women are on NLBs Supervisory Board?
# 276           What is responsible for the supervision of the correct implementation?
# 277                 What percentage of current employees are NLB Group core members?
# 278  What did the survey on ethics and compliance with the NLB and in the strateg...
# 279              What is one of the key responsibilities of the Sustainability unit?
# 280                                     How many employees worked from home in 2022?
# 281  What is prepared according to Article 17 of the Regulation on internal gover...
# 282     By 2025, what will be the share of active digital retail users in NLB Group?
# 283  When did the NLB Group offer customers loans with a sustainable financing co...
# 284  What does NLB ensure by having a common understanding of and complying with ...
# 285                 How many different sets of activities were provided in Sarajevo?
# 286  What percentage of all employees are covered by a system that has been inter...
# 287              How many big taxpayers had mutual trust status in Slovenia in 2020?
# 288               By 2022, how much of new corporate financing has been implemented?
# 289  What is the name of the school of economics and business of the University o...
# 290      What is the acronym for the Internal Liquidity Adequacy Assessment Process?
# 291              How many companies participated in the FrameOfHelp project in 2022?
# 292                                                                    What is ESMA?
# 293             What defines the values and basic rules of ethical business conduct?
# 294                                            When was Komercijalna Banka acquired?
# 295                                     What percentage of employees work from home?
# 296                                      How many subsidiary banks are in SE Europe?
# 297                               How many employees did the NLB Group have in 2019?
# 298  How many kilometers did we drive in 2020 using electric cars for business pu...
# 299                              In 2022, ESG goals were considered as part of what?
# 300                     By 2025, what percentage of paper prints were to be reduced?
# 301   What is one of the activities that the Group does not finance that is illegal?
# 302  What does NLB Group align its core strategy, decision-making, lending and in...
# 303                           What is the purpose of the Customer Experience Survey?
# 304                       What title goes to a branch where employees work together?
# 305   How many employees took part in training programmes in the baseline year 2019?
# 306                                What are NLB d.d.s operations in accordance with?
# 307  How many main stakeholder groups did the NLB Group identify through stakehol...
# 308                How much of managers in the second management level are women in?
# 309                     How much of all card transactions in NLB go through NLB Pay?
# 310                                     What does NLB Group give high importance to?
# 311          Who has the influence over sustainability-related strategic objectives?
# 312  What defines expectations and determines standards expected in our relations...
# 313              How does the Bank implement the principles of the Diversity Policy?
# 314                          What describes the management process and organization?
# 315  When did several important activities start for the purpose of calculation o...
# 316  What will exposures that are not fully supported by published Taxonomy repor...
# 317                                   How many sports clubs did NLB support in 2022?
# 318          How many workshops were organized specifically for older peoples needs?
# 319                                How many countries does the NLB Group operate in?
# 320                                         How many active clients does Group have?
# 321          NLB Pay is a mobile wallet that enables contactless payments with what?
# 322            What does the Sustainable Development unit make proposals related to?
# 323                                        What does NLB Group operate in line with?
# 324   How much CO2 did we reduce by using electric vehicles instead of liquid fuels?
# 325       How many modules did the 2022 ECB Climate Stress test exercise consist of?
# 326                                                How many behaviours were defined?
# 327  How much did the bank reduce the use of paper in 2022 compared to the previo...
# 328             What are the key strategic areas of operations of the Group in 2020?
# 329          What percentage of NLB Group employees have a tertiary education level?
# 330  In what year did the Bank sign a Contract of Guarantees with the Multilatera...
# 331                       What is the name of the Non-Financial Reporting Directive?
# 332                              How many targets did the NLB Bank announce in 2021?
# 333          How many branches does NLB Group have in all markets where it operates?
# 334                  How many Slovenian companies joined the GREENVISION initiative?
# 335                          What do employees in banks possess better knowledge of?
# 336                                                        What does ECRA stand for?
# 337               In 2022, how many hours/employee did NLB employees do in training?
# 338                           How many material issues did Senior Management assess?
# 339  What other measures are there for reducing costs and streamlining the Banks ...
# 340                                                     How many trees did NLB save?
# 341                                         How many trees were planted on Jahorina?
# 342          When was the impact analysis based on the UN PRB methodology conducted?
# 343                   What percentage of all employees have been internally audited?
# 344  By 2030, what percentage of all electric energy used in NLB Group will come ...
# 345          When was Komercijalna Banka a.d. Beograd and its subsidiaries finished?
# 346                            How many countries are there in which we are present?
# 347                What percentage of the Bank is owned by the Republic of Slovenia?
# 348                        What does the report accurately and completely represent?
# 349                                           Who is the leader of the SHIMMPO team?
# 350                                   How many clients does Komercijalna banka have?
# 351                                  How many employees took parental leave in 2022?
# 352                 How many shareholders did the Supervisory Board address in 2022?
# 353      In what year were concrete targets included in the Banks performance plans?
# 354                                                                What is the ESMS?
# 355                             How many employees took part in training programmes?
# 356                     How many employees are on the Komercijna Banka banking team?
# 357                   What is the framework for reporting non-financial information?
# 358                                             Where is Komercijalna banka located?
# 359                                      What does NLB Group aim to achieve in 2022?
# 360                    What is the acronym for the European Social Market Authority?
# 361                         How many employees were in NLB Group at the end of 2020?
# 362        How many new employees were employed by the Republic of Slovenia in 2020?
# 363         How many participants took part in standard training programmes in 2020?
# 364  How much new green loan volume did NLB Group generate for micro and corporat...
# 365                                         What type of structure does H stand for?
# 366                          Compliance and integrity were established in what year?
# 367       What is one of the most important building blocks of the Banks governance?
# 368        How many consecutive years did Top Employer receive the First ESG Rating?
# 369                                      What percentage of those who left were men?
# 370  What defines the basic goals and principles of protection of people, facilit...
# 371                      In what year did NLB Group organize its first Investor Day?
# 372                                           What is the share capital of the bank?
# 373                                                    What does ESMS aim to manage?
# 374                               How many employees departed from NLB d.d. in 2020?
# 375  How can employees report potentially non-ethical or inappropriate business p...
# 376                                 Who implemented the Women in Business programme?
# 377  How much of all electricity used in NLB Group will come from zero-carbon sou...
# 378  In what year did the NLB Group become a signatory to the UN PRB and UNEP FI ...
# 379                What was the turnover rate in NLB Group in 2022 compared to 2021?
# 380      What percentage of electricity was obtained from zero carbon energy source?
# 381                          How much sustainable corporate financing did we create?
# 382  How much electricity was purchased from zero-carbon sources in two largest a...
# 383     What is Slovenias most important and renowned network of advanced companies?
# 384                                 How many trees did the bank donate to Prishtina?
# 385  What country allows customers to do business remotely 24 hours a day, 7 days...
# 386                                       What is an inspiration for all of society?
# 387            What percentage of female managers were women at the end of the year?
# 388                                         How many women are in Management Boards?
# 389  When did the programme evolve into a comprehensive NLB Group Sustainability ...
# 390                      What was the consumption of various resources converted to?
# 391           When was the acquisition of Komercijalna Banka a.d. Beograd completed?
# 392  In 2022, how many hours were recorded in education about sustainability topics?
# 393                                                        When was Net established?
# 394          How many employees departed from NLB Group significant members in 2020?
# 395                         What type of paper is used per employee per working day?
# 396                        Who are the directors that are subordinated to B-2 level?
# 397  In what two cities did the electricity consumption decrease between 6% and 9...
# 398  What year was it possible to detect the activities of banks in the Slovenian...
# 399                                        What is the name of the Social GRI Topic?
# 400          What was NLB Group rated as low risk by ESG Risk rating Sustainalytics?
# 401  What does the Guide to fit and proper assessments of the European Central Ba...
# 402                      What was the percentage of staff with disabilities in 2020?
# 403                              What does the NLB Groups Code of Conduct establish?
# ...
# 465  to identify areas of improvement or areas where we excel compared to our com...
# 466                                                                Workers’ Council
# 467                                                                           4,769
# 468                   the Rules on the Prevention of Harassment and Mobbing at Work
# 469                                                                               3
# 470                                                                             55%
# 471                                                                           12.3%
# 472                            the risk culture and awareness of all relevant risks
# 473                                                                       ESG risks
# 474                                                            a calibration system
# 475                                  the Bank also sets the framework for diversity
# 476                                                          Performance management
# 477                                                                               2
# 478                                                       exposures to undertakings
# 479                                                                              10
# 480                                                                A series of four
# 481                                                                          1-2/emp
# 482                                                                               8
# 483                                        smartphones equipped with NFC technology
# 484  ESG risks and opportunities related to climate and other sustainability cons...
# 485                                                                 Code of Conduct
# 486                                                                             15%
# 487                                                                           three
# 488                                                     changing customer behaviour
# 489                                                                             17%
# 490                          Digitalisation, client centricity, and cost efficiency
# 491                                                                             98%
# 492                                                                            2020
# 493                                                       Statement of Independence
# 494                                                                               4
# 495                                                                             440
# 496                                                                      almost 100
# 497                          highly motivated and included in the Bank’s operations
# 498                                              Foreign Account Tax Compliance Act
# 499                                                                              18
# 500                                                                           301-1
# 501                           zero tolerance and prohibition of any form of mobbing
# 502                                                                             866
# 503                                                                            2100
# 504                                                                            2022
# 505                                                                              10
# 506                                                                            100%
# 507                                                                      April 2022
# 508                                                            individual countries
# 509                                                                             25%
# 510                                                  climate and environmental data
# 511                                                                Bogdan Darmanovi
# 512                                                                    2.11 million
# 513                                                                             382
# 514                                                                             382
# 515                                                                             None
# 516                                                     Progress Procurement policy
# 517                                                                             70%
# 518                                                                             53%
# 519                                                                             None
# 520                                                                         Beograd
# 521                                                              Target achivements
# 522                                              NLB Group Sustainability Framework
# 523                                                                             382
# 524                                                                              94
# 525                                                                           4,769
# 526
# 527                                                           External tax controls
# 528                                                                            2020
# 529  Transparency of operations ensuring quality disclosures, frequency of inform...
# 530                                                                              28
# 531                                                                           35.6%
# 532                                               The NLB Corporate Security Policy
# 533                                                                            2022
# 534                                                                             25%
# 535                                                             sustainable finance
# 536                                                                             162
# 537                            with procedures and measures to avoid or reduce them
# 538                                            the competent financial institutions
# 539                                                                            100%
# 540                                                                            2020
# 541                                                                              6%
# 542                                                                             10%
# 543                                                                            2022
# 544                                                                            100%
# 545                                                              Komercijalna banka
# 546                                                                     Seventy-six
# 547                                                                        Slovenia
# 548                                                                Digital literacy
# 549                                                                             56%
# 550                                                                             56%
# 551                                                                     August 2022
# 552                                                                             MWh
# 553                                                                      April 2022
# 554                                                                          25,502
# 555                                                                            2017
# 556                                                                             382
# 557                                                                        4 format
# 558                                                                General Managers
# 559                                                    15 compared to 2021, and 10%
# 560                                                                            2020
# 561                                                    GRI Disclosure Value Comment
# 562                                      Environmental and Social Management System
# 563                                                                      the policy
# 564                                                                              2%
# 565                            uniform rules of conduct for all NLB Group employees
# 566                                                                             None
# 567                                                                            2022
# 568  Occupational Health and Safety Disclosure 403-2 Hazard identification, risk ...
# 569                                                                             98%
# 570                                                                             None
# 571                                                                     once a year
# 572                                                                              24
# 573                                                                             50%
# 574                                                                  ESG guidelines
# 575                                                                             None
# 576                                                                           5,000
# 577                                                               internal training
# 578                                   the industry itself but also on the companies
# 579                                                     Total number and percentage
# 580                                                                       NLB Group
# 581                                           transparency in NLB operations Groups
# 582                      special routes of movement in the workplaces, for visitors
# 583                                                                            2022
# 584                     direct postal delivery or via appearance in the post office
# 585                                                                             None
# 586                                           https://www.nlb.si/corporate-overnance
# 587                                              Foreign Account Tax Compliance Act
# 588    implemented controls in the field of information security and cyber security
# 589                                                                            2023
# 590                                                                            2021
# 591                                                                    space-demand
# 592                                                                31 December 2022
# 593                                                                              17
# 594                                new and significant changes to existing products
# 595                                                                            2022
# 596                                                                              20
# 597                                                                               3
# 598                                                     Progress Procurement policy
# 599                                                                             31%
# 600                                                                    competent OU,
# 601                                                                             97%
# 602  Sustainability Framework Human Rights Regulation & Governance GRI Standards ...
# 603                                 Stakeholder engagement on sustainability topics
# 604                                                                             382
# 605                                                   Internal Control System (ICS)
# 606                                                                             55%
# 607                                                    within regulatory timeframes
# 608                                           strong culture of business compliance
# 609                                                                              19
# 610                                                                            100%
# 611                                                                              11
# 612                                                                             17%
# 613                                                                       Bankarium
# 614                                                     Regulatory Compliance Check
# 615                                                                             300
# 616                                                      Sustainability Report 2022
# 617                                                                              P>
# 618                                                                      April 2022
# 619                                                                             42%
# 620                                                                            nine
# 621                                                                             307
# 622                                                                          17,297
# 623                                                                     suppli- ers
# 624                                                                             50%
# 625                                                           Political involvement
# 626                                                        the Group Business Model
# 627  to identify areas of improvement or areas where we excel compared to our com...
# 628                                            Workers’ Council and the Trade Union
# 629                                                                           4,769
# 630                       Rules on the Prevention of Harassment and Mobbing at Work
# 631                                                                              13
# 632                                                                             55%
# 633                                                                           12.3%
# 634        risk culture and awareness of all relevant risks within the entire Group
# 635       The Group is strategically focused on contributing to sustainable finance
# 636                                                          Performance management
# 637  sets the framework for diversity regarding education, the range of knowledge...
# 638                                                            a calibration system
# 639                                                                     end of 2022
# 640                                                                             None
# 641                                                                             202
# 642                                                                             None
# 643
# 644                                                                             None
# 645                                        smartphones equipped with NFC technology
# 646                                  climate and other sustainability considerations
# 647                                               the workplace or location of work

# %%
# split the dataset bz model
for model in results_df["Model"].unique():
    model_df = results_df[results_df["Model"] == model]
    model_df.to_csv(f"../../data/results/2042-combined/{model}-outputs.csv", index=False)
